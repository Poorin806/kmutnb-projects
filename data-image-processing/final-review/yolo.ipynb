# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
from ultralytics import YOLO

import cv2

# %%
model = YOLO("yolo11n-seg.yaml").load("yolo11n.pt")  # build from YAML and transfer weights
results = model.train(data="./dataset.yaml", epochs=100, imgsz=640)
# Out:
# Transferred 499/561 items from pretrained weights
# New https://pypi.org/project/ultralytics/8.3.213 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.205  Python-3.13.5 torch-2.8.0+cpu CPU (12th Gen Intel Core i7-1260P)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=./dataset.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n-seg.yaml, momentum=0.937, mosaic=1.0, multi_scale=False, name=train4, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=yolo11n.pt, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\Poorin\Documents\KMUTNB\kmutnb-projects\data-image-processing\final-review\runs\segment\train4, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=segment, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    684025  ultralytics.nn.modules.head.Segment          [3, 32, 64, [64, 128, 256]]
# YOLO11n-seg summary: 203 layers, 2,843,193 parameters, 2,843,177 gradients, 9.7 GFLOPs
#
# Transferred 510/561 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# train: Fast image access  (ping: 0.40.2 ms, read: 7.37.0 MB/s, size: 165.9 KB)
# train: Scanning C:\Users\Poorin\Documents\KMUTNB\kmutnb-projects\data-image-processing\global-datasets\x-any-labeling\labels... 13 images, 9 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 22/22 85.8it/s 0.3ss
# train: New cache created: C:\Users\Poorin\Documents\KMUTNB\kmutnb-projects\data-image-processing\global-datasets\x-any-labeling\labels.cache
# val: Fast image access  (ping: 0.00.0 ms, read: 759.0447.6 MB/s, size: 300.9 KB)
# val: Scanning C:\Users\Poorin\Documents\KMUTNB\kmutnb-projects\data-image-processing\global-datasets\x-any-labeling\labels.cache... 13 images, 9 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 22/22 22.6Kit/s 0.0s
# Plotting labels to C:\Users\Poorin\Documents\KMUTNB\kmutnb-projects\data-image-processing\final-review\runs\segment\train4\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 90 weight(decay=0.0), 101 weight(decay=0.0005), 100 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to C:\Users\Poorin\Documents\KMUTNB\kmutnb-projects\data-image-processing\final-review\runs\segment\train4
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       1/100         0G     0.4915      9.083      3.489      1.102         11        640: 100% ━━━━━━━━━━━━ 2/2 0.0it/s 46.7s43.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 0.1it/s 10.1s
#                    all         22         13      0.002          1      0.235      0.207    0.00109      0.533      0.106     0.0337
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       2/100         0G     0.5693      8.623      3.345      1.075         11        640: 100% ━━━━━━━━━━━━ 2/2 0.1it/s 23.1s0.5s
# WARNING NMS time limit 3.100s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 0.1it/s 12.5s
#                    all         22         13    0.00207          1      0.186      0.166    0.00157      0.767     0.0951     0.0336
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       3/100         0G     0.5962      7.279      3.262      1.086         12        640: 100% ━━━━━━━━━━━━ 2/2 0.1it/s 19.0s22.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 0.1it/s 8.6s
#                    all         22         13    0.00216          1      0.229      0.211    0.00145        0.7      0.113     0.0504
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       4/100         0G      0.708      6.572      3.602      1.238          9        640: 100% ━━━━━━━━━━━━ 2/2 0.1it/s 19.6s19.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 0.1it/s 11.7s
#                    all         22         13     0.0022          1      0.322      0.286     0.0017      0.767      0.197     0.0885
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       5/100         0G     0.5735      5.547       3.26      1.119         12        640: 100% ━━━━━━━━━━━━ 2/2 0.1it/s 26.6s0.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 0.1it/s 10.9s
#                    all         22         13    0.00227          1      0.373      0.332    0.00176      0.767      0.202      0.107
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       6/100         0G     0.4648      5.163      3.386      1.126          9        640: 100% ━━━━━━━━━━━━ 2/2 0.1it/s 22.8s19.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 0.1it/s 9.4s
#                    all         22         13    0.00224          1      0.428      0.382    0.00208      0.917      0.245      0.123
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       7/100         0G     0.3775      4.663      3.094     0.9337         12        640: 100% ━━━━━━━━━━━━ 2/2 0.1it/s 18.9s16.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 0.1it/s 8.4s
#                    all         22         13    0.00223          1      0.382      0.348    0.00212      0.917      0.368      0.147
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       8/100         0G     0.5396      3.931      3.073       1.04         13        640: 100% ━━━━━━━━━━━━ 2/2 0.1it/s 16.2s14.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 0.1it/s 8.6s
#                    all         22         13    0.00225          1      0.499      0.438    0.00225          1      0.465      0.272
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       9/100         0G     0.6575      3.317       3.73      1.061          5        640: 100% ━━━━━━━━━━━━ 2/2 0.1it/s 17.6s17.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 0% ──────────── 0/1  10.5s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 model = YOLO("yolo11n-seg.yaml").load("yolo11n.pt")  # build from YAML and transfer weights
# ----> 2 results = model.train(data="./dataset.yaml", epochs=100, imgsz=640)
#
# File c:\Users\Poorin\anaconda3\Lib\site-packages\ultralytics\engine\model.py:800, in Model.train(self, trainer, **kwargs)
#     797     self.trainer.model = self.trainer.get_model(weights=self.model if self.ckpt else None, cfg=self.model.yaml)
#     798     self.model = self.trainer.model
# --> 800 self.trainer.train()
#     801 # Update model and cfg after training
#     802 if RANK in {-1, 0}:
#
# File c:\Users\Poorin\anaconda3\Lib\site-packages\ultralytics\engine\trainer.py:235, in BaseTrainer.train(self)
#     232         ddp_cleanup(self, str(file))
#     234 else:
# --> 235     self._do_train()
#
# File c:\Users\Poorin\anaconda3\Lib\site-packages\ultralytics\engine\trainer.py:473, in BaseTrainer._do_train(self)
#     471 if self.args.val or final_epoch or self.stopper.possible_stop or self.stop:
#     472     self._clear_memory(threshold=0.5)  # prevent VRAM spike
# --> 473     self.metrics, self.fitness = self.validate()
#     474 self.save_metrics(metrics={**self.label_loss_items(self.tloss), **self.metrics, **self.lr})
#     475 self.stop |= self.stopper(epoch + 1, self.fitness) or final_epoch
#
# File c:\Users\Poorin\anaconda3\Lib\site-packages\ultralytics\engine\trainer.py:687, in BaseTrainer.validate(self)
#     679 def validate(self):
#     680     """
#     681     Run validation on val set using self.validator.
#     682
#    (...)
#     685         fitness (float): Fitness score for the validation.
#     686     """
# --> 687     metrics = self.validator(self)
#     688     fitness = metrics.pop("fitness", -self.loss.detach().cpu().numpy())  # use loss as fitness measure if not found
#     689     if not self.best_fitness or self.best_fitness < fitness:
#
# File c:\Users\Poorin\anaconda3\Lib\site-packages\torch\utils\_contextlib.py:120, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     117 @functools.wraps(func)
#     118 def decorate_context(*args, **kwargs):
#     119     with ctx_factory():
# --> 120         return func(*args, **kwargs)
#
# File c:\Users\Poorin\anaconda3\Lib\site-packages\ultralytics\engine\validator.py:223, in BaseValidator.__call__(self, trainer, model)
#     221 # Postprocess
#     222 with dt[3]:
# --> 223     preds = self.postprocess(preds)
#     225 self.update_metrics(preds, batch)
#     226 if self.args.plots and batch_i < 3:
#
# File c:\Users\Poorin\anaconda3\Lib\site-packages\ultralytics\models\yolo\segment\val.py:109, in SegmentationValidator.postprocess(self, preds)
#      99 """
#     100 Post-process YOLO predictions and return output detections with proto.
#     101
#    (...)
#     106     list[dict[str, torch.Tensor]]: Processed detection predictions with masks.
#     107 """
#     108 proto = preds[1][-1] if len(preds[1]) == 3 else preds[1]  # second output is len 3 if pt, but only 1 if exported
# --> 109 preds = super().postprocess(preds[0])
#     110 imgsz = [4 * x for x in proto.shape[2:]]  # get image size from proto
#     111 for i, pred in enumerate(preds):
#
# File c:\Users\Poorin\anaconda3\Lib\site-packages\ultralytics\models\yolo\detect\val.py:119, in DetectionValidator.postprocess(self, preds)
#     108 def postprocess(self, preds: torch.Tensor) -> list[dict[str, torch.Tensor]]:
#     109     """
#     110     Apply Non-maximum suppression to prediction outputs.
#     111
#    (...)
#     117             'bboxes', 'conf', 'cls', and 'extra' tensors.
#     118     """
# --> 119     outputs = nms.non_max_suppression(
#     120         preds,
#     121         self.args.conf,
#     122         self.args.iou,
#     123         nc=0 if self.args.task == "detect" else self.nc,
#     124         multi_label=True,
#     125         agnostic=self.args.single_cls or self.args.agnostic_nms,
#     126         max_det=self.args.max_det,
#     127         end2end=self.end2end,
#     128         rotated=self.args.task == "obb",
#     129     )
#     130     return [{"bboxes": x[:, :4], "conf": x[:, 4], "cls": x[:, 5], "extra": x[:, 6:]} for x in outputs]
#
# File c:\Users\Poorin\anaconda3\Lib\site-packages\ultralytics\utils\nms.py:155, in non_max_suppression(prediction, conf_thres, iou_thres, classes, agnostic, multi_label, labels, max_det, nc, max_time_img, max_nms, max_wh, rotated, end2end, return_idxs)
#     152 if "torchvision" in sys.modules:
#     153     import torchvision  # scope as slow import
# --> 155     i = torchvision.ops.nms(boxes, scores, iou_thres)
#     156 else:
#     157     i = TorchNMS.nms(boxes, scores, iou_thres)
#
# File c:\Users\Poorin\anaconda3\Lib\site-packages\torchvision\ops\boxes.py:48, in nms(boxes, scores, iou_threshold)
#      46     _log_api_usage_once(nms)
#      47 _assert_has_ops()
# ---> 48 return torch.ops.torchvision.nms(boxes, scores, iou_threshold)
#
# File c:\Users\Poorin\anaconda3\Lib\site-packages\torch\_ops.py:1243, in OpOverloadPacket.__call__(self, *args, **kwargs)
#    1241 if self._has_torchbind_op_overload and _must_dispatch_in_python(args, kwargs):
#    1242     return _call_overload_packet_from_python(self, *args, **kwargs)
# -> 1243 return self._op(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
model = YOLO("./runs/segment/train3/weights/last.pt")
img = cv2.imread("../global-datasets/x-any-labeling/test/cat2.jpg")
result = model.predict(source=img, imgsz=640, conf=0.01)
# Out:
# 0: 384x640 1 cat, 1 tiger, 157.5ms
# Speed: 2.8ms preprocess, 157.5ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)

# %%
mask = result[0].masks.xy
overlay = img.copy()
image = img.copy()

mbox = result[0]
# class_id = result[0].boxes.cls
# confidence = result[0].boxes.conf

for box in mbox.boxes:
  class_id = mbox.names[box.cls[0].item()]
  cords = box.xyxy[0].tolist()
  cords = [round(i) for i in cords]

  color = (0, 255, 0)  # Green color for the mask
  if (box.cls[0].item() == 0):  # Assuming class 0 is one category
      color = (0, 255, 0)  # Green for class 0
  elif (box.cls[0].item() == 1):  # Assuming class 1 is another category
      color = (255, 0, 0)  # Blue for class 1
  elif (box.cls[0].item() == 2):  # Assuming class
      color = (0, 0, 255)  # Red for class 2

  conf = round(box.conf[0].item(), 2)
  image = cv2.rectangle(image, (cords[0], cords[1]), (cords[2], cords[3]), color, 2)
  image = cv2.putText(image, f'{class_id} {conf}', (cords[0], cords[1]-10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0,0,0), 2)
  print(class_id, cords)

# Polygon Mask
for i in range(len(mask)):

    x = mask[i].astype(int)
    pts = x.reshape((-1, 1, 2))
    image = cv2.polylines(image, [pts], isClosed=True, color=(0,0,255), thickness=2)
    overlay = cv2.fillPoly(overlay, pts=[pts], color=(0,0,255))
    alpha = 0.5  # Transparency factor
    image = cv2.addWeighted(overlay, alpha, image, 1 - alpha, 0)
    # r = 600.0/image.shape[0]
    # dim = (600, int(image.shape[0]*r))

    # pts = mask[i].astype(int)
    # cv2.fillPoly(overlay, [pts], color)
    # alpha = 0.5  # Transparency factor
    # image = cv2.addWeighted(overlay, alpha, image, 1 - alpha, 0)

cv2.imshow("Predict", image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# cat [261, 41, 973, 540]
# tiger [212, 41, 973, 537]
