# %%
a = 0x59
print(a)
# Out:
# 89

# %%
b = "\u0043\u0041\u0052"

for i in b:
  print(i, ord(i), chr(ord(i) + 5))
# Out:
# C 67 H
# A 65 F
# R 82 W

# %%
f = (1, 2, 3)
# dir(f)

# %%
len(f)
for i in f: print(i, end=" ")
print()
for i in range(len(f)): print(i, end=" ")
# Out:
# 1 2 3
# 0 1 2

# %%
h = {
  'id': "cat",
  'age': 51
}

for i in h.keys(): print(i, h[i])
# Out:
# id cat
# age 51

# %%
data = {}
print(data)
# Out:
# {}

# %%
data["id"] = "123"
data["name"] = "Poorin"

print(data)

del data["name"]

print(data)
