# %%
from fastapi import FastAPI
import asyncio
import uvicorn

app = FastAPI()

# Route (Maybe work with controllers)
@app.get("/")
def root():
  return {
    "message": "App is running!"
  }

@app.get("/courses/{name}")
def get_course_name(name):
  return {
    "message": f"Course:  {name}"
  }

# %%
if __name__ == "__main__":
  config = uvicorn.Config(app)
  server = uvicorn.Server(config)
  await server.serve()
# Out:
# INFO:     Started server process [13524]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     127.0.0.1:52908 - "GET /courses/poorin HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57643 - "GET /docs HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57643 - "GET /openapi.json HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52909 - "GET /courses/Poorin%20Thatsakhon HTTP/1.1" 200 OK
# INFO:     127.0.0.1:61546 - "GET /openapi.json HTTP/1.1" 200 OK
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [13524]
